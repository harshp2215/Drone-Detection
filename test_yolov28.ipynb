# %%
from ultralytics import YOLO

# %%
model = YOLO(r"runs/detect/train3/weights/best.pt")

# %%
model.predict(
    source="final_dataset/images/test",
    save=True,
    save_crop=True,
    conf=0.25
)
# Out:
# image 1/700 c:\Users\Divya\skills\minor_project\final_dataset\images\test\aero_ (106).jpg: 640x640 1 aeroplane, 8.2ms
# image 2/700 c:\Users\Divya\skills\minor_project\final_dataset\images\test\aero_ (109).jpg: 640x640 1 aeroplane, 9.7ms
# image 3/700 c:\Users\Divya\skills\minor_project\final_dataset\images\test\aero_ (115).jpg: 640x640 1 aeroplane, 8.4ms
# image 4/700 c:\Users\Divya\skills\minor_project\final_dataset\images\test\aero_ (120).jpg: 640x640 1 aeroplane, 8.0ms
# image 5/700 c:\Users\Divya\skills\minor_project\final_dataset\images\test\aero_ (142).jpg: 640x640 1 aeroplane, 7.8ms
# image 6/700 c:\Users\Divya\skills\minor_project\final_dataset\images\test\aero_ (147).jpg: 640x640 1 aeroplane, 8.5ms
# image 7/700 c:\Users\Divya\skills\minor_project\final_dataset\images\test\aero_ (148).jpg: 640x640 1 aeroplane, 8.5ms
# image 8/700 c:\Users\Divya\skills\minor_project\final_dataset\images\test\aero_ (176).jpg: 640x640 1 aeroplane, 8.6ms
# ...
